# %% [markdown]
# # NumPy Mastery — Notebook 07
# ## Final NumPy Practice & Capstone
#
# ### Mission
# This is the **final notebook of the original 7-notebook NumPy plan**.
#
# The goal is NOT to suddenly make NumPy much harder. The goal is to:
# 1. revise everything learned so far,
# 2. practice the remaining concepts supported by your NumPy study material,
# 3. combine concepts in realistic problems,
# 4. prepare for the transition to Pandas.
#
# ### Important
# This notebook stays within the concepts covered by your supplied NumPy material. It does **not** introduce unrelated functions such as `np.where()`, `np.argsort()`, `np.searchsorted()`, or the `np.random` module.
#
# ### Learning pattern
# Quick Revision → Remaining Concepts → Warm-up → Core → Real World → Integration → Final Capstone → Interview → Reflection

# %% [markdown]
# # 1. Complete NumPy Revision
#
# Before solving, quickly review these groups.
#
# ### Array creation
# `np.array()`, `np.zeros()`, `np.ones()`, `np.full()`, `np.eye()`, `np.arange()`, `np.linspace()`
#
# ### Properties
# `shape`, `size`, `ndim`, `dtype`, `itemsize`
#
# ### Data types
# `astype()`
#
# ### Indexing & slicing
# Basic indexing, fancy indexing, Boolean indexing, slicing, copy vs view
#
# ### Multi-dimensional arrays
# Rows, columns, axes, 1D / 2D / 3D thinking
#
# ### Axis operations
# `axis=0`, `axis=1`
#
# ### Reshaping
# `reshape()`, `flatten()`, `ravel()`, transpose, `hstack()`, `vstack()`, `concatenate()`, `split()`, `array_split()`
#
# ### Vectorization & broadcasting
# Scalar broadcasting, vector broadcasting, compatible shapes, normalization
#
# ### Aggregation & statistics
# `sum()`, `prod()`, `min()`, `max()`, `argmin()`, `argmax()`, `mean()`, `median()`, `std()`, `var()`
#
# ### Mathematical functions
# `square()`, `sqrt()`, `pow()`, `log()`, `log10()`, `log2()`, `exp()`
#
# ### Rounding
# `round()`, `ceil()`, `floor()`, `trunc()`
#
# ### Other
# `abs()`, `sort()`, `unique()`
#
# Your supplied material explicitly covers these groups and also notes that additional built-in functions may be learned in later chapters. This notebook therefore stays with the covered foundation rather than adding unrelated APIs.

# %% [markdown]
# # 2. Remaining / Easy-to-forget Concepts
#
# These are the concepts we want to make sure you can actually use before leaving NumPy:
#
# - `np.zeros()`
# - `np.ones()`
# - `np.full()`
# - `np.eye()`
# - `np.linspace()`
# - `dtype` and `astype()`
# - `itemsize`
# - `prod()`
# - `ravel()`
# - `array_split()`
# - `concatenate()` with `axis`
# - `transpose()`
# - 2D axis operations
# - `round()`, `ceil()`, `floor()`, `trunc()`
# - `log`, `log10`, `log2`, `exp`
# - vector normalization
# - copy vs view
# - combining multiple NumPy operations

# %% [markdown]
# # 3. Complete Datasets
#
# Run this cell before starting the exercises.

# %%
import numpy as np

# Student marks: 20 students
marks = np.array([
    78, 65, 91, 45, 82,
    56, 99, 73, 68, 88,
    59, 77, 84, 93, 61,
    70, 80, 54, 97, 66
])

# Employee salaries
salary = np.array([
    25000, 32000, 45000, 60000, 72000,
    85000, 40000, 52000, 90000, 31000,
    68000, 47000, 75000, 83000, 39000
])

# Monthly sales
sales = np.array([
    1200, 1450, 1320, 1680,
    1750, 1900, 2100, 2050,
    1980, 2200, 2400, 2600
])

# Customer IDs with duplicates
customer_ids = np.array([
    101, 102, 103, 104, 101,
    105, 106, 107, 102, 108,
    109, 110, 110, 111, 112
])

# 2D student marks: 4 subjects x 5 students
student_marks = np.array([
    [78, 65, 91, 45, 82],
    [56, 99, 73, 68, 88],
    [59, 77, 84, 93, 61],
    [70, 80, 54, 97, 66]
])

# Decimal values for mathematical and rounding practice
prices = np.array([99.456, 125.789, 49.125, 210.678, 75.999])

# Small array for copy/view and unique practice
arr = np.array([12, 5, 18, 5, 9, 21, 12, 7, 18, 3])

# %% [markdown]
# # 4. Warm-up — 10 Problems
#
# These are direct revision questions.

# %% [markdown]
# ### Problem 1
#
# Create an array of five zeros with `np.zeros()`.

# %% [markdown]
# ### Problem 2
#
# Create an array of five ones with `np.ones()`.

# %% [markdown]
# ### Problem 3
#
# Create a 3 × 4 matrix filled with 7 using `np.full()`.

# %% [markdown]
# ### Problem 4
#
# Create a 4 × 4 identity matrix using `np.eye()`.

# %% [markdown]
# ### Problem 5
#
# Create 10 equally spaced values from 0 to 100 using `np.linspace()`.

# %% [markdown]
# ### Problem 6
#
# Display the `shape`, `size`, `ndim`, `dtype`, and `itemsize` of `student_marks`.

# %% [markdown]
# ### Problem 7
#
# Convert `marks` to `float64` using `astype()` without changing the original `marks` array.

# %% [markdown]
# ### Problem 8
#
# Find the product of `[2, 3, 4, 5]` using `np.prod()`.

# %% [markdown]
# ### Problem 9
#
# Sort `arr` and then remove duplicates using `np.unique()`.

# %% [markdown]
# ### Problem 10
#
# Transpose `student_marks` and check its new shape.

# %% [markdown]
# # 5. Core Practice — 15 Problems
#
# Combine two or three concepts at a time.

# %% [markdown]
# ### Problem 11
#
# Create `np.arange(1, 21)` and reshape it into a 4 × 5 matrix.

# %% [markdown]
# ### Problem 12
#
# Create values from 10 to 50 using `np.linspace()` and reshape them into a 5 × 2 matrix.

# %% [markdown]
# ### Problem 13
#
# Create a 3 × 3 matrix of 1s and add 5 using broadcasting.

# %% [markdown]
# ### Problem 14
#
# Create a 3 × 3 matrix of 10s and subtract the row vector `[1, 2, 3]` using broadcasting.

# %% [markdown]
# ### Problem 15
#
# Using `student_marks`, calculate the total for each row and the total for each column using the correct axis.

# %% [markdown]
# ### Problem 16
#
# Using `student_marks`, calculate the mean for each row and each column.

# %% [markdown]
# ### Problem 17
#
# Find the highest mark in each row using `np.max()` with an axis.

# %% [markdown]
# ### Problem 18
#
# Find the index of the highest value in each row using `np.argmax()` with an axis.

# %% [markdown]
# ### Problem 19
#
# Flatten `student_marks`, sort it, and extract the 5 highest marks.

# %% [markdown]
# ### Problem 20
#
# Split the sorted marks into 4 equal parts using `np.split()`.

# %% [markdown]
# ### Problem 21
#
# Use `np.array_split()` to divide `marks` into 6 parts. Check the sizes of the resulting arrays.

# %% [markdown]
# ### Problem 22
#
# Join two arrays with `np.concatenate()` along axis 0 and explain what changed.

# %% [markdown]
# ### Problem 23
#
# Transpose `student_marks`, then calculate the mean of each column of the transposed result.

# %% [markdown]
# ### Problem 24
#
# Use `np.round()`, `np.ceil()`, `np.floor()`, and `np.trunc()` on `prices` and compare their results.

# %% [markdown]
# ### Problem 25
#
# Calculate `np.square()`, `np.sqrt()`, and `np.pow()` on a small positive integer array.

# %% [markdown]
# # 6. Real-World Practice — 10 Problems
#
# Use NumPy as a data-analysis tool.

# %% [markdown]
# ### Problem 26
#
# Student Analysis: calculate mean, median, standard deviation, and variance of `marks`.

# %% [markdown]
# ### Problem 27
#
# Student Analysis: find the number of students above the mean and below the mean using Boolean indexing.

# %% [markdown]
# ### Problem 28
#
# Student Analysis: create a sorted copy of `marks`, extract the top 5 and bottom 5, and compare their averages.

# %% [markdown]
# ### Problem 29
#
# Salary Analysis: calculate the total salary, average salary, highest salary, lowest salary, and salary range.

# %% [markdown]
# ### Problem 30
#
# Salary Analysis: convert salaries from rupees to lakhs using vectorization and round the result to 2 decimal places.

# %% [markdown]
# ### Problem 31
#
# Sales Analysis: reshape the 12 monthly sales values into 4 quarters with 3 months per quarter, then calculate each quarter's total.

# %% [markdown]
# ### Problem 32
#
# Sales Analysis: calculate the percentage contribution of each month to total yearly sales using vectorized operations.

# %% [markdown]
# ### Problem 33
#
# Customer Data: find unique customer IDs, total records, unique customers, and duplicate-record count.

# %% [markdown]
# ### Problem 34
#
# Data Preprocessing: standardize `sales` using `(sales - mean) / std` and verify that the resulting mean is approximately 0 and standard deviation is approximately 1.

# %% [markdown]
# ### Problem 35
#
# Image-style Data: create a 3 × 4 grayscale pixel matrix with values from 0 to 255, then find its shape, maximum pixel value, minimum pixel value, mean pixel value, and transpose.

# %% [markdown]
# # 7. Integration Practice — 8 Problems
#
# These are the final bridge problems before the capstone.

# %% [markdown]
# ### Problem 41
#
# Create two arrays of equal length, add them using vectorization, then reshape the result into a matrix.

# %% [markdown]
# ### Problem 42
#
# Create a 4 × 3 matrix and a 1 × 3 row vector. Use broadcasting to add the row vector to every row.

# %% [markdown]
# ### Problem 43
#
# Create a 4 × 3 matrix and a 4 × 1 column vector. Use broadcasting to add the column vector to every column.

# %% [markdown]
# ### Problem 44
#
# Take `marks`, create a copy, add 5 marks using vectorization, and identify values that would exceed 100 using Boolean indexing. Do not use a new function that has not been taught.

# %% [markdown]
# ### Problem 45
#
# Take `prices` and produce a clean report containing rounded, ceiling, floor, and truncated versions.

# %% [markdown]
# ### Problem 46
#
# Take `student_marks`, flatten it, sort it, find unique values, and calculate the mean and standard deviation of the unique values.

# %% [markdown]
# ### Problem 47
#
# Create a 2D array, make both a `flatten()` result and a `ravel()` result, change an element in each result, and observe whether the original changes.

# %% [markdown]
# ### Problem 48
#
# Build a 2D preprocessing pipeline: convert integer data to float, calculate the column mean and standard deviation, then normalize each column using broadcasting.

# %% [markdown]
# # 8. 🏆 Final NumPy Capstone — Student & Sales Analytics
#
# ## Scenario
#
# You are working as a junior data analyst. You have student marks, salaries, monthly sales, and customer records.
#
# Build one complete NumPy analysis.
#
# ### Part A — Dataset inspection
# 1. Display shape, size, ndim, dtype, and itemsize for the major datasets.
# 2. Convert the dataset you need to `float64` with `astype()`.
#
# ### Part B — Student analysis
# 3. Calculate mean, median, standard deviation, and variance.
# 4. Find highest and lowest marks.
# 5. Find the indices of the highest and lowest marks.
# 6. Sort the marks.
# 7. Extract top 5 and bottom 5.
# 8. Find values above and below the average.
# 9. Reshape marks where appropriate and perform axis-based calculations.
#
# ### Part C — Sales analysis
# 10. Reshape monthly sales into quarters.
# 11. Calculate quarterly totals.
# 12. Calculate monthly percentage contribution.
# 13. Normalize the sales values.
# 14. Verify the normalized mean and standard deviation.
#
# ### Part D — Customer analysis
# 15. Find unique customer IDs.
# 16. Calculate duplicate-record count.
#
# ### Part E — Mathematical preprocessing
# 17. Use at least three mathematical functions from the course.
# 18. Use at least two rounding functions.
# 19. Demonstrate vectorization.
# 20. Demonstrate broadcasting.
#
# ### Final requirement
#
# Create a short printed summary containing your most important results.
#
# ### Rules
#
# - NumPy only.
# - No Pandas.
# - No Python `for` loops.
# - Do not use functions that have not been taught.
# - Keep the original datasets unchanged where possible by creating copies.

# %% [markdown]
# # 9. 🎤 Final NumPy Interview Questions
#
# Answer these without looking at your notes.
#
# 1. What is the difference between `axis=0` and `axis=1` in a 2D array?
# 2. What is the difference between `flatten()` and `ravel()`?
# 3. What is broadcasting, and why is it useful in machine learning?
# 4. What is the difference between `argmax()` and `max()`?
# 5. Why might `astype()` be important when preparing data for machine learning?
# 6. What is the difference between `np.sort()` and `np.unique()`?
# 7. Why is vectorization usually preferred over explicit Python loops for NumPy calculations?
# 8. Explain standard normalization using mean and standard deviation.

# %% [markdown]
# # 10. 🧠 Final NumPy Checklist
#
# Before moving to Pandas, you should be able to answer **yes** to most of these:
#
# - [ ] I can create arrays in multiple ways.
# - [ ] I understand `shape`, `size`, `ndim`, `dtype`, and `itemsize`.
# - [ ] I can index and slice 1D and 2D arrays.
# - [ ] I understand Boolean and fancy indexing.
# - [ ] I understand copy vs view.
# - [ ] I can use axes confidently.
# - [ ] I can reshape and transpose arrays.
# - [ ] I can concatenate, stack, and split arrays.
# - [ ] I understand broadcasting.
# - [ ] I can perform vectorized calculations.
# - [ ] I can calculate basic statistics.
# - [ ] I can sort and find unique values.
# - [ ] I can use mathematical and rounding functions.
# - [ ] I can normalize an array.
# - [ ] I can combine several NumPy operations to solve a real problem.

# %% [markdown]
# # 11. 📝 Final Reflection
#
# - My strongest NumPy topic:
# - My weakest NumPy topic:
# - Function I still confuse:
# - Biggest mistake I made across the 7 notebooks:
# - Concept I understand much better now:
# - Confidence in NumPy (1–10):
# - What I will revise before the 100–150 mixed questions:
# - What I am most excited to learn in Pandas:
