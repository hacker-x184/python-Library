# %% [markdown]
# # 01 Matplotlib — Practice & Visualization
#
# **Level:** Beginner → Intermediate
#
# **Total Practice Questions:** 70+
#
# This notebook follows the same learning style as the Pandas practice sheet: quick revision → focused practice → practical analysis → combined challenges → mini project.
#
# ## How to use this notebook
# 1. Read the revision notes before each section.
# 2. Try the exercises yourself first.
# 3. Do not copy solutions immediately.
# 4. Run the code and inspect the visualization.
# 5. Ask yourself what information the graph communicates.
# 6. Write observations for analytical questions.

# %% [markdown]
# ## Setup
#
# Run this setup before beginning the exercises.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Matplotlib Basics
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q1.1
#
# Import `matplotlib.pyplot` using the standard alias.

# %%
# Write your solution here
import matplotlib.pyplot as plt

# %% [markdown]
# ### Q1.2
#
# Create x = [1, 2, 3, 4, 5] and y = [2, 4, 6, 8, 10], then create a basic line plot.

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x,y)

# %% [markdown]
# ### Q1.3
#
# Display the plot using `plt.show()`.

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Q1.4
#
# Change the y values and observe how the graph changes.

# %%
y = [4,5,7,6,0]
plt.plot(x,y)
plt.show()

# %% [markdown]
# # 2. Figure and Axes
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q2.1
#
# Create a figure and axes using `plt.subplots()`.

# %%
x2 = [32,65,78,4]
y2 = [44,67,83,5]
plt.subplot(2,2,1)
plt.plot(x,y)

plt.subplot(2,2,2)
plt.plot(x2,y2)

plt.subplot(2,2,3)
plt.plot(x2,y2)

plt.subplot(2,2,4)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Q2.2
#
# Plot a line using the axes object.

# %%
fig,ax = plt.subplots(2,2)
ax[0,0].plot(x,y)
ax[0,1].plot(x2,y2)
ax[1,0].plot(x2,y2)
ax[1,1].plot(x,y)
plt.show()

# %% [markdown]
# ### Q2.3
#
# Add a title using the axes object.

# %%
fig,ax = plt.subplots(2,2)
ax[0,0].plot(x,y)
ax[0,1].plot(x2,y2)
ax[1,0].plot(x2,y2)
ax[1,1].plot(x,y)
ax[0,0].set_title("Graph - 1")
ax[0,1].set_title("Graph - 2")
ax[1,0].set_title("Graph - 3")
ax[1,1].set_title("Graph - 4")
plt.tight_layout()
plt.legend(ax)
plt.grid()
plt.show()

# %% [markdown]
# ### Q2.4
#
# Add x-axis and y-axis labels.

# %%
x = [5,10,15,20,25]
y = [10,15,20,25,30]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# # 3. Basic Line Plot
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q3.1
#
# Plot numbers 1–5 against their squares.

# %%
x= [1,2,3,4,5]
y = []
for i in x:
    x1 = i**2
    y.append(x1)
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Q3.2
#
# Plot daily sales for seven days.

# %%
days = [1, 2, 3, 4, 5, 6, 7]
sales = [120, 150, 130, 180, 220, 200, 250]
plt.plot(days,sales)
plt.xlabel("Days")
plt.ylabel("sales")
plt.title("Data")
plt.legend()
plt.grid()
# Out:
# C:\Users\inzam\AppData\Local\Temp\ipykernel_22544\350513807.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Q3.3
#
# Add a meaningful title and axis labels.

# %%
days = [1, 2, 3, 4, 5, 6, 7]
sales = [120, 150, 130, 180, 220, 200, 250]
plt.plot(days,sales)
plt.xlabel("Days")
plt.ylabel("sales")
plt.title("Data")
plt.legend()
plt.grid()
# Out:
# C:\Users\inzam\AppData\Local\Temp\ipykernel_22544\1899344849.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### Q3.4
#
# Add markers to the line.

# %%
plt.plot(days,sales,marker = "s")

# %% [markdown]
# ### Q3.5
#
# Change the line style.

# %%
plt.plot(days,sales,marker = "s",linestyle="--")

# %% [markdown]
# ### Q3.6
#
# Change the marker style.

# %%
plt.plot(days,sales,marker = "s",linestyle="--",markersize=5)

# %% [markdown]
# ### Q3.7
#
# Add a grid.

# %%
days = [1, 2, 3, 4, 5, 6, 7]
sales = [120, 150, 130, 180, 220, 200, 250]
plt.plot(days,sales,marker = "s",linestyle="--")
plt.xlabel("Days")
plt.ylabel("sales")
plt.title("Data")
plt.legend()
plt.grid()
# Out:
# C:\Users\inzam\AppData\Local\Temp\ipykernel_22544\3512688974.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # 4. Multiple Lines
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q4.1
#
# Create Product A and Product B sales data and plot both on one graph.

# %%
days = [1, 2, 3, 4, 5, 6, 7]
product_A_sales = [120, 150, 140, 180, 200, 220, 250]
product_B_sales = [100, 130, 160, 150, 190, 210, 230]
plt.plot(days,product_A_sales,label="data-1",marker = "*",linestyle = "--",color = "blue")
plt.plot(days,product_B_sales,label="data-2",marker = "*",linestyle = ("solid"),color = "Green")
plt.legend()
plt.grid()

# %% [markdown]
# ### Q4.2
#
# Add a legend identifying both products.

# %%
days = [1, 2, 3, 4, 5, 6, 7]
product_A_sales = [120, 150, 140, 180, 200, 220, 250]
product_B_sales = [100, 130, 160, 150, 190, 210, 230]
plt.plot(days,product_A_sales,label="data-1",marker = "*",linestyle = "--",color = "blue")
plt.plot(days,product_B_sales,label="data-2",marker = "*",linestyle = ("solid"),color = "Green")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Q4.3
#
# Use different markers for the two products.

# %%
days = [1, 2, 3, 4, 5, 6, 7]
product_A_sales = [120, 150, 140, 180, 200, 220, 250]
product_B_sales = [100, 130, 160, 150, 190, 210, 230]
plt.plot(days,product_A_sales,label="data-1",marker = "*",linestyle = "--",color = "blue")
plt.plot(days,product_B_sales,label="data-2",marker = "*",linestyle = ("solid"),color = "Green")
plt.legend()
plt.grid()

# %% [markdown]
# ### Q4.4
#
# Use different line styles for the two products.

# %%
days = [1, 2, 3, 4, 5, 6, 7]
product_A_sales = [120, 150, 140, 180, 200, 220, 250]
product_B_sales = [100, 130, 160, 150, 190, 210, 230]
plt.plot(days,product_A_sales,label="Product-A",marker = "*",linestyle = "--",color = "blue")
plt.plot(days,product_B_sales,label="Product-B",marker = "*",linestyle = ("solid"),color = "Green")
plt.legend()
plt.grid()

# %% [markdown]
# ### Q4.5
#
# Identify which product has the higher overall trend.

# %%
days = [1, 2, 3, 4, 5, 6, 7]
product_A_sales = [120, 150, 140, 180, 200, 220, 250]
product_B_sales = [100, 130, 160, 150, 190, 210, 230]
plt.plot(days,product_A_sales,label="Product-A",marker = "*",linestyle = "--",color = "blue")
plt.plot(days,product_B_sales,label="Product-B",marker = "*",linestyle = ("solid"),color = "Green")
plt.legend(loc="upper left")

# %% [markdown]
# # 5. Plot Customization
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q5.1
#
# Create a sales graph and add a meaningful title.

# %%
plt.plot(sales,product_A_sales,marker="s",color="red",linestyle=("--"),markersize = 5,label="Product A")
plt.plot(sales,product_B_sales,marker="*",color="blue",linestyle=("solid"),markersize = 10,label="Product B")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Q5.2
#
# Add x-axis and y-axis labels.

# %%
plt.plot(sales,product_A_sales,marker="s",color="red",linestyle=("--"),markersize = 5,label="Product A")
plt.plot(sales,product_B_sales,marker="*",color="blue",linestyle=("solid"),markersize = 10,label="Product B")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Q5.3
#
# Add a legend.

# %%
plt.plot(sales,product_A_sales,marker="s",color="red",linestyle=("--"),markersize = 5,label="Product A")
plt.plot(sales,product_B_sales,marker="*",color="blue",linestyle=("solid"),markersize = 10,label="Product B")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Q5.4
#
# Add a grid.

# %%
plt.plot(sales,product_A_sales,marker="s",color="red",linestyle=("--"),markersize = 5,label="Product A")
plt.plot(sales,product_B_sales,marker="*",color="blue",linestyle=("solid"),markersize = 10,label="Product B")
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Q5.5
#
# Set suitable x-axis limits.

# %%
plt.plot(sales,product_A_sales,marker="s",color="red",linestyle=("--"),markersize = 5,label="Product A")
plt.plot(sales,product_B_sales,marker="*",color="blue",linestyle=("solid"),markersize = 10,label="Product B")
plt.grid()
plt.legend()
plt.xlim(100,200)
plt.show()

# %% [markdown]
# ### Q5.6
#
# Set suitable y-axis limits.

# %%
plt.plot(sales,product_A_sales,marker="s",color="red",linestyle=("--"),markersize = 5,label="Product A")
plt.plot(sales,product_B_sales,marker="*",color="blue",linestyle=("solid"),markersize = 10,label="Product B")
plt.grid()
plt.legend()
plt.xlim(100,200)
plt.ylim(100,160)
plt.show()

# %% [markdown]
# ### Q5.7
#
# Customize x-axis ticks.

# %%
plt.plot(sales,product_A_sales,marker="s",color="red",linestyle=("--"),markersize = 5,label="Product A")
plt.plot(sales,product_B_sales,marker="*",color="blue",linestyle=("solid"),markersize = 10,label="Product B")
plt.grid()
plt.legend()
plt.xlim(100,200)
plt.ylim(100,160)
plt.xticks(
    [120, 150, 130, 180, 220, 200, 250],
    ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
)
plt.show()

# %% [markdown]
# ### Q5.8
#
# Customize y-axis ticks.

# %%
days = [1, 2, 3, 4, 5, 6, 7]

product_A_sales = [120, 150, 140, 180, 200, 220, 250]
product_B_sales = [100, 130, 160, 150, 190, 210, 230]

plt.plot(
    days,
    product_A_sales,
    label="Product-A",
    marker="*",
    linestyle="--",
    color="blue"
)

plt.plot(
    days,
    product_B_sales,
    label="Product-B",
    marker="*",
    linestyle="solid",
    color="green"
)

plt.xlim(1, 7)
plt.ylim(80, 270)

plt.xticks(
    [1, 2, 3, 4, 5, 6, 7],
    ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
)

plt.yticks([80, 100, 120, 140, 160, 180, 200, 220, 240, 260])

plt.xlabel("Days")
plt.ylabel("Sales")
plt.title("Product Sales")

plt.grid()
plt.legend(loc="upper left")

plt.show()

# %% [markdown]
# ### Q5.9
#
# Create a professional-looking final chart.

# %%
days = [1, 2, 3, 4, 5, 6, 7]
product_A_sales = [120, 150, 140, 180, 200, 220, 250]
product_B_sales = [100, 130, 160, 150, 190, 210, 230]
plt.plot(
    days,
    product_A_sales,
    label="Product-A",
    marker="*",
    linestyle="--",
    color="blue"
)
plt.plot(
    days,
    product_B_sales,
    label="Product-B",
    marker="*",
    linestyle="solid",
    color="green"
)
plt.xlim(1, 7)
plt.ylim(80, 270)
plt.xticks(
    [1, 2, 3, 4, 5, 6, 7],
    ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
)
plt.yticks([80, 100, 120, 140, 160, 180, 200, 220, 240, 260])
plt.xlabel("Days")
plt.ylabel("Sales")
plt.title("Product Sales")
plt.grid()
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 6. Line Plot — Practical Analysis
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q6.1
#
# Create monthly sales data for six months and plot it.

# %%
months = [
    "January", "February", "March", "April",
    "May", "June", "July", "August",
    "September", "October", "November", "December"
]
product_A_sales = [1200, 1350, 1280, 1500, 1650, 1720, 1800, 1750, 1900, 2100, 2300, 2500]
product_B_sales = [1000, 1150, 1250, 1380, 1450, 1550, 1620, 1700, 1780, 1950, 2150, 2250]
plt.plot(months,product_A_sales)
plt.plot(months,product_B_sales)
plt.tight_layout()

# %% [markdown]
# ### Q6.2
#
# Identify the highest-sales month.

# %%
max(product_A_sales)
# Out:
# 2500

# %% [markdown]
# ### Q6.3
#
# Identify the lowest-sales month.

# %%
product_A_sales.index(max(product_A_sales))
# Out:
# 11

# %% [markdown]
# ### Q6.4
#
# Add markers and data labels.

# %%
# Out:
# 'December'

# %% [markdown]
# ### Q6.5
#
# Write three observations about the trend.

# %%
# Write your solution here

# %% [markdown]
# # 7. Scatter Plot
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q7.1
#
# Create Study Hours = [1,2,3,4,5,6] and Marks = [45,50,55,65,72,80].

# %%
# Write your solution here

# %% [markdown]
# ### Q7.2
#
# Create a scatter plot.

# %%
# Write your solution here

# %% [markdown]
# ### Q7.3
#
# Add title and axis labels.

# %%
# Write your solution here

# %% [markdown]
# ### Q7.4
#
# Change marker size.

# %%
# Write your solution here

# %% [markdown]
# ### Q7.5
#
# Create two student groups and plot them on the same axes.

# %%
# Write your solution here

# %% [markdown]
# ### Q7.6
#
# Observe whether study hours and marks appear related.

# %%
# Write your solution here

# %% [markdown]
# # 8. Scatter Plot — Practical Analysis
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q8.1
#
# Create sample Age and Salary data and make a scatter plot.

# %%
# Write your solution here

# %% [markdown]
# ### Q8.2
#
# Create Experience and Salary data and make a scatter plot.

# %%
# Write your solution here

# %% [markdown]
# ### Q8.3
#
# Compare the two relationships.

# %%
# Write your solution here

# %% [markdown]
# ### Q8.4
#
# Write three observations.

# %%
# Write your solution here

# %% [markdown]
# # 9. Bar Chart
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q9.1
#
# Create subject-wise marks for five subjects and make a bar chart.

# %%
# Write your solution here

# %% [markdown]
# ### Q9.2
#
# Add a title and axis labels.

# %%
# Write your solution here

# %% [markdown]
# ### Q9.3
#
# Display values above the bars.

# %%
# Write your solution here

# %% [markdown]
# ### Q9.4
#
# Create a horizontal bar chart using the same data.

# %%
# Write your solution here

# %% [markdown]
# ### Q9.5
#
# Compare which visualization is easier to read.

# %%
# Write your solution here

# %% [markdown]
# # 10. Grouped Bar Chart
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q10.1
#
# Create monthly sales for Product A and Product B.

# %%
# Write your solution here

# %% [markdown]
# ### Q10.2
#
# Create a grouped bar chart.

# %%
# Write your solution here

# %% [markdown]
# ### Q10.3
#
# Add a legend.

# %%
# Write your solution here

# %% [markdown]
# ### Q10.4
#
# Add title and axis labels.

# %%
# Write your solution here

# %% [markdown]
# ### Q10.5
#
# Identify the month with the highest combined sales.

# %%
# Write your solution here

# %% [markdown]
# # 11. Bar Chart — Placement Analysis
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q11.1
#
# Create Department, Total Students and Placed Students data.

# %%
# Write your solution here

# %% [markdown]
# ### Q11.2
#
# Compare total students by department.

# %%
# Write your solution here

# %% [markdown]
# ### Q11.3
#
# Compare placed students by department.

# %%
# Write your solution here

# %% [markdown]
# ### Q11.4
#
# Add labels and a legend.

# %%
# Write your solution here

# %% [markdown]
# ### Q11.5
#
# Write three observations.

# %%
# Write your solution here

# %% [markdown]
# # 12. Histogram
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q12.1
#
# Generate marks for 30 students and create a histogram.

# %%
# Write your solution here

# %% [markdown]
# ### Q12.2
#
# Add a title and axis labels.

# %%
# Write your solution here

# %% [markdown]
# ### Q12.3
#
# Try 5 bins.

# %%
# Write your solution here

# %% [markdown]
# ### Q12.4
#
# Try 10 bins.

# %%
# Write your solution here

# %% [markdown]
# ### Q12.5
#
# Try 20 bins.

# %%
# Write your solution here

# %% [markdown]
# ### Q12.6
#
# Compare the different bin settings.

# %%
# Write your solution here

# %% [markdown]
# ### Q12.7
#
# Identify the most common score range.

# %%
# Write your solution here

# %% [markdown]
# # 13. Salary Distribution
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q13.1
#
# Create salary-package data for placed students.

# %%
# Write your solution here

# %% [markdown]
# ### Q13.2
#
# Create a histogram.

# %%
# Write your solution here

# %% [markdown]
# ### Q13.3
#
# Experiment with the number of bins.

# %%
# Write your solution here

# %% [markdown]
# ### Q13.4
#
# Identify the most common salary range.

# %%
# Write your solution here

# %% [markdown]
# ### Q13.5
#
# Look for possible extreme values.

# %%
# Write your solution here

# %% [markdown]
# ### Q13.6
#
# Write three observations.

# %%
# Write your solution here

# %% [markdown]
# # 14. Pie Chart
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q14.1
#
# Create five expense categories and their values.

# %%
# Write your solution here

# %% [markdown]
# ### Q14.2
#
# Create a pie chart.

# %%
# Write your solution here

# %% [markdown]
# ### Q14.3
#
# Add category labels.

# %%
# Write your solution here

# %% [markdown]
# ### Q14.4
#
# Display percentages.

# %%
# Write your solution here

# %% [markdown]
# ### Q14.5
#
# Separate the largest category.

# %%
# Write your solution here

# %% [markdown]
# ### Q14.6
#
# Write two observations.

# %%
# Write your solution here

# %% [markdown]
# # 15. Box Plot
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q15.1
#
# Create student marks and make a box plot.

# %%
# Write your solution here

# %% [markdown]
# ### Q15.2
#
# Identify the median visually.

# %%
# Write your solution here

# %% [markdown]
# ### Q15.3
#
# Observe the spread.

# %%
# Write your solution here

# %% [markdown]
# ### Q15.4
#
# Add an extreme value and inspect the possible outlier.

# %%
# Write your solution here

# %% [markdown]
# # 16. Compare Distributions
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q16.1
#
# Create marks for Class A, Class B and Class C.

# %%
# Write your solution here

# %% [markdown]
# ### Q16.2
#
# Create box plots for all three classes.

# %%
# Write your solution here

# %% [markdown]
# ### Q16.3
#
# Compare their medians.

# %%
# Write your solution here

# %% [markdown]
# ### Q16.4
#
# Compare their spread.

# %%
# Write your solution here

# %% [markdown]
# ### Q16.5
#
# Look for possible outliers.

# %%
# Write your solution here

# %% [markdown]
# ### Q16.6
#
# Decide which class appears most consistent.

# %%
# Write your solution here

# %% [markdown]
# # 17. Subplots
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q17.1
#
# Create a 2×2 figure.

# %%
# Write your solution here

# %% [markdown]
# ### Q17.2
#
# Add a line plot.

# %%
# Write your solution here

# %% [markdown]
# ### Q17.3
#
# Add a bar chart.

# %%
# Write your solution here

# %% [markdown]
# ### Q17.4
#
# Add a scatter plot.

# %%
# Write your solution here

# %% [markdown]
# ### Q17.5
#
# Add a histogram.

# %%
# Write your solution here

# %% [markdown]
# ### Q17.6
#
# Give every subplot a suitable title.

# %%
# Write your solution here

# %% [markdown]
# # 18. Pandas + Matplotlib
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q18.1
#
# Create a DataFrame containing Month, Sales, Expenses and Profit.

# %%
# Write your solution here

# %% [markdown]
# ### Q18.2
#
# Plot monthly Sales.

# %%
# Write your solution here

# %% [markdown]
# ### Q18.3
#
# Plot monthly Expenses.

# %%
# Write your solution here

# %% [markdown]
# ### Q18.4
#
# Plot monthly Profit.

# %%
# Write your solution here

# %% [markdown]
# ### Q18.5
#
# Compare Sales and Expenses.

# %%
# Write your solution here

# %% [markdown]
# ### Q18.6
#
# Create a combined visualization.

# %%
# Write your solution here

# %% [markdown]
# ### Q18.7
#
# Write five observations.

# %%
# Write your solution here

# %% [markdown]
# # 19. Student Placement Visualization
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q19.1
#
# Use a dataset containing branch, cgpa, coding_skills, internships, projects_count, placement_status and salary_package_lpa.

# %%
# Write your solution here

# %% [markdown]
# ### Q19.2
#
# Create a branch-wise student count chart.

# %%
# Write your solution here

# %% [markdown]
# ### Q19.3
#
# Create a placement-status chart.

# %%
# Write your solution here

# %% [markdown]
# ### Q19.4
#
# Plot CGPA distribution.

# %%
# Write your solution here

# %% [markdown]
# ### Q19.5
#
# Plot coding-skills distribution.

# %%
# Write your solution here

# %% [markdown]
# ### Q19.6
#
# Plot CGPA versus placement.

# %%
# Write your solution here

# %% [markdown]
# ### Q19.7
#
# Plot internships versus placement.

# %%
# Write your solution here

# %% [markdown]
# ### Q19.8
#
# Plot coding skills versus placement.

# %%
# Write your solution here

# %% [markdown]
# ### Q19.9
#
# Plot salary distribution only for placed students.

# %%
# Write your solution here

# %% [markdown]
# ### Q19.10
#
# Compare branch-wise placement.

# %%
# Write your solution here

# %% [markdown]
# ### Q19.11
#
# Write five observations.

# %%
# Write your solution here

# %% [markdown]
# # 20. Combined Analytics Challenge
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q20.1
#
# Visualize the distribution of every important numerical column.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.2
#
# Visualize important categorical columns.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.3
#
# Compare placed and unplaced students.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.4
#
# Compare CGPA between placed and unplaced students.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.5
#
# Compare coding skills between placed and unplaced students.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.6
#
# Analyze internships.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.7
#
# Analyze projects.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.8
#
# Analyze salary distribution.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.9
#
# Analyze branch-wise placement.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.10
#
# Analyze college-tier placement if available.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.11
#
# Create at least five meaningful charts.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.12
#
# Choose the most appropriate chart for each analytical question.

# %%
# Write your solution here

# %% [markdown]
# ### Q20.13
#
# Write ten observations.

# %%
# Write your solution here

# %% [markdown]
# # 21. Independent Challenge
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q21.1
#
# Using a larger dataset, create visualizations without step-by-step hints.

# %%
# Write your solution here

# %% [markdown]
# ### Q21.2
#
# Identify the most important numerical distributions.

# %%
# Write your solution here

# %% [markdown]
# ### Q21.3
#
# Identify the most important categorical distributions.

# %%
# Write your solution here

# %% [markdown]
# ### Q21.4
#
# Compare important groups.

# %%
# Write your solution here

# %% [markdown]
# ### Q21.5
#
# Find visible trends.

# %%
# Write your solution here

# %% [markdown]
# ### Q21.6
#
# Find possible outliers.

# %%
# Write your solution here

# %% [markdown]
# ### Q21.7
#
# Create at least five meaningful charts.

# %%
# Write your solution here

# %% [markdown]
# ### Q21.8
#
# Explain why each chart type was selected.

# %%
# Write your solution here

# %% [markdown]
# # 22. Visualization Quality Challenge
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q22.1
#
# Take one earlier chart and improve its title.

# %%
# Write your solution here

# %% [markdown]
# ### Q22.2
#
# Improve axis labels.

# %%
# Write your solution here

# %% [markdown]
# ### Q22.3
#
# Improve tick readability.

# %%
# Write your solution here

# %% [markdown]
# ### Q22.4
#
# Add a legend if required.

# %%
# Write your solution here

# %% [markdown]
# ### Q22.5
#
# Add a grid only where useful.

# %%
# Write your solution here

# %% [markdown]
# ### Q22.6
#
# Choose an appropriate figure size.

# %%
# Write your solution here

# %% [markdown]
# ### Q22.7
#
# Remove unnecessary visual elements.

# %%
# Write your solution here

# %% [markdown]
# ### Q22.8
#
# Save the improved figure as a PNG file.

# %%
# Write your solution here

# %% [markdown]
# # 23. Final Mini Project — Student Performance Analytics
#
# ## Quick Revision
#
# Review the relevant Matplotlib concept before attempting the exercises.
#
# ## Practice

# %% [markdown]
# ### Q23.1
#
# Create a dataset containing Student, Marks, Attendance, Study Hours and Department.

# %%
# Write your solution here

# %% [markdown]
# ### Q23.2
#
# Create a histogram for marks distribution.

# %%
# Write your solution here

# %% [markdown]
# ### Q23.3
#
# Create a bar chart for student/subject comparison.

# %%
# Write your solution here

# %% [markdown]
# ### Q23.4
#
# Create a scatter plot for Study Hours versus Marks.

# %%
# Write your solution here

# %% [markdown]
# ### Q23.5
#
# Create an attendance visualization.

# %%
# Write your solution here

# %% [markdown]
# ### Q23.6
#
# Create at least one comparison visualization by department.

# %%
# Write your solution here

# %% [markdown]
# ### Q23.7
#
# Add appropriate titles, labels, legends, grids and figure sizes.

# %%
# Write your solution here

# %% [markdown]
# ### Q23.8
#
# Write at least ten analytical observations.

# %%
# Write your solution here

# %% [markdown]
# ### Q23.9
#
# Explain which visualization was most useful and why.

# %%
# Write your solution here

# %% [markdown]
# # Final Revision Checklist
#
# ## Basics
# - [ ] pyplot
# - [ ] figure
# - [ ] axes
# - [ ] plot()
# - [ ] show()
#
# ## Line plots
# - [ ] Multiple lines
# - [ ] Markers
# - [ ] Line styles
# - [ ] Titles
# - [ ] Labels
# - [ ] Legends
# - [ ] Grid
# - [ ] Ticks
# - [ ] Axis limits
#
# ## Other visualizations
# - [ ] Scatter plots
# - [ ] Bar charts
# - [ ] Grouped bar charts
# - [ ] Histograms
# - [ ] Pie charts
# - [ ] Box plots
# - [ ] Subplots
#
# ## Data Analysis
# - [ ] Pandas + Matplotlib
# - [ ] Distribution analysis
# - [ ] Group comparison
# - [ ] Trend analysis
# - [ ] Outlier observation
# - [ ] Chart selection
# - [ ] Analytical observations
# - [ ] Saving figures
#
# ## Final Goal
# Do not only learn how to make graphs. Learn how to choose the correct visualization, interpret it, and convert the visualization into useful analytical conclusions.
